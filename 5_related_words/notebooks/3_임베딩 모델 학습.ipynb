# %%
import pandas as pd

# %%
df = pd.read_csv("../data/video_sample_20241013.csv", encoding="utf-8-sig", index_col=0)
df
# Out:
#           video_id                channel_id  \
# 0      O-6ixtlqe5k  UC-_4Zo69CRpMiFzXv7mn9pw
# 1      Q1Cv5lJqWQ4  UC5_AgLKYa-MHGLvXLM-AVsQ
# 2      JmrEd_vzD4c  UC6_aivuPSLO4pAnqoP6LSJQ
# 3      VljtSv_U6lg  UCi_hv8HtknRKHy0rxt6VA6w
# 4      z4SYw3YRfJA  UCW_FuZhIDZMr-AJzBZg7F8A
# ...            ...                       ...
# 27923  _WMoI-6naAM  UCzznO4xSV8BKnUBPyswtCUw
# 27924  s3kBS7-cjIM  UCzznO4xSV8BKnUBPyswtCUw
# 27925  eg8lrIpFxyU  UCzznO4xSV8BKnUBPyswtCUw
# 27926  AhXtATajoZU  UCzznO4xSV8BKnUBPyswtCUw
# 27927  JBan0Oy8fVE  UCZZZHqYbfPpq6noP2DH6B7w
#
#                                              video_title  \
# 0                                   2024 여름끝 스파이더 충주호 투어
# 1      다발능이버섯이 씽씽하게 올라 오고  있다 능이버섯 많이 보고 왔어요 2024년 10...
# 2               토익 PART5 출제 예상 고난이도 빈출 60문제 이렇게 연습해보세요✍️
# 3                                무릎 박리성골연골염4 - 엑스레이, MRI
# 4                 하마스 땅굴과 헤즈볼라 땅굴은 북한땅굴입니다.(남굴사대표 김진철목사)
# ...                                                  ...
# ...
